# %%
import pandas as pd   # data preprocessing
pd.set_option('display.max_columns', None) # to display all columns
import matplotlib.pyplot as plt  # data visualization
import seaborn as sns  # data visualization

import warnings
warnings.filterwarnings('ignore') # would not show unnecessary warning messages

# %%
police_Shootings =pd.read_csv(r"C:\Users\OJ SYSTEMS\Documents\shootings.csv")
police_Shootings.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender      race           city state  signs_of_mental_illness threat_level  \
# 0      M     Asian        Shelton    WA                     True       attack
# 1      M     White          Aloha    OR                    False       attack
# 2      M  Hispanic        Wichita    KS                    False        other
# 3      M     White  San Francisco    CA                     True       attack
# 4      M  Hispanic          Evans    CO                    False       attack
#
#           flee  body_camera          arms_category
# ...

# %%
police_Shootings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4895 entries, 0 to 4894
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       4895 non-null   int64
#  1   name                     4895 non-null   object
#  2   date                     4895 non-null   object
#  3   manner_of_death          4895 non-null   object
#  4   armed                    4895 non-null   object
#  5   age                      4895 non-null   float64
#  6   gender                   4895 non-null   object
#  7   race                     4895 non-null   object
#  8   city                     4895 non-null   object
#  9   state                    4895 non-null   object
#  10  signs_of_mental_illness  4895 non-null   bool
#  11  threat_level             4895 non-null   object
#  12  flee                     4895 non-null   object
#  13  body_camera              4895 non-null   bool
# ...

# %%
# write a print statement that shows the shape of the data. You could use f-string or .format()
# then display the first 12 rows, still in this cell
shape_data = police_Shootings.shape
print("\nthe shape of the police Shootings data is {}".format(shape_data))
police_Shootings.head(12)
# Out:
# the shape of the police Shootings data is (4895, 15)
#     id                 name        date   manner_of_death       armed   age  \
# 0    3           Tim Elliot  2015-01-02              shot         gun  53.0
# 1    4     Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2    5   John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3    8      Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4    9    Michael Rodriguez  2015-01-04              shot    nail gun  39.0
# 5   11    Kenneth Joe Brown  2015-01-04              shot         gun  18.0
# 6   13  Kenneth Arnold Buck  2015-01-05              shot         gun  22.0
# 7   15        Brock Nichols  2015-01-06              shot         gun  35.0
# 8   16        Autumn Steele  2015-01-06              shot     unarmed  34.0
# 9   17      Leslie Sapp III  2015-01-06              shot  toy weapon  47.0
# 10  19       Patrick Wetter  2015-01-06  shot and Tasered       knife  25.0
# ...

# %%
# below this code line, write a markdown that describes the data you've just loaded
#The data above is a compilation of different events of police shootings

# %% [markdown]
# #The data above is a compilation of different events of police shootings

# %%
#check how many null values exists in the data
police_Shootings.isnull().sum()
# Out:
# id                         0
# name                       0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# arms_category              0
# dtype: int64

# %%
# check the statistical distribution of the data
police_Shootings.describe(include= "all")
# Out:
#                  id   name        date manner_of_death armed          age  \
# count   4895.000000   4895        4895            4895  4895  4895.000000
# unique          NaN   4851        1792               2    89          NaN
# top             NaN  TK TK  2018-06-29            shot   gun          NaN
# freq            NaN     29           9            4647  2755          NaN
# mean    2902.148519    NaN         NaN             NaN   NaN    36.549750
# std     1683.467910    NaN         NaN             NaN   NaN    12.694348
# min        3.000000    NaN         NaN             NaN   NaN     6.000000
# 25%     1441.500000    NaN         NaN             NaN   NaN    27.000000
# 50%     2847.000000    NaN         NaN             NaN   NaN    35.000000
# 75%     4352.500000    NaN         NaN             NaN   NaN    45.000000
# max     5925.000000    NaN         NaN             NaN   NaN    91.000000
#
#        gender   race         city state signs_of_mental_illness threat_level  \
# ...

# %%
# we may want to extract information based on the years police shooting ocurred most
# but the date column is of the format year-month-day. So, split the column using "-", and drop the
# month and day column, while keeping the year along side the rest of the other column.
# the year column should bear *year*

# %%
df=police_Shootings

# %%
df[["year","month","day"]] = df["date"].str.split("-",expand = True)
df
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
df.drop(columns=["date"],inplace = True)

# %%
df.head()
# Out:
#    id                name   manner_of_death       armed   age gender  \
# 0   3          Tim Elliot              shot         gun  53.0      M
# 1   4    Lewis Lee Lembke              shot         gun  47.0      M
# 2   5  John Paul Quintero  shot and Tasered     unarmed  23.0      M
# 3   8     Matthew Hoffman              shot  toy weapon  32.0      M
# 4   9   Michael Rodriguez              shot    nail gun  39.0      M
#
#        race           city state  signs_of_mental_illness threat_level  \
# 0     Asian        Shelton    WA                     True       attack
# 1     White          Aloha    OR                    False       attack
# 2  Hispanic        Wichita    KS                    False        other
# 3     White  San Francisco    CA                     True       attack
# 4  Hispanic          Evans    CO                    False       attack
#
#           flee  body_camera          arms_category  year month day
# ...

# %%
df.shape
# Out:
# (4895, 17)

# %%
df.drop(columns=["month"],inplace = True)
df.head()
# Out:
#    id                name   manner_of_death       armed   age gender  \
# 0   3          Tim Elliot              shot         gun  53.0      M
# 1   4    Lewis Lee Lembke              shot         gun  47.0      M
# 2   5  John Paul Quintero  shot and Tasered     unarmed  23.0      M
# 3   8     Matthew Hoffman              shot  toy weapon  32.0      M
# 4   9   Michael Rodriguez              shot    nail gun  39.0      M
#
#        race           city state  signs_of_mental_illness threat_level  \
# 0     Asian        Shelton    WA                     True       attack
# 1     White          Aloha    OR                    False       attack
# 2  Hispanic        Wichita    KS                    False        other
# 3     White  San Francisco    CA                     True       attack
# 4  Hispanic          Evans    CO                    False       attack
#
#           flee  body_camera          arms_category  year day
# 0  Not fleeing        False                   Guns  2015  02
# ...

# %%
df.shape
# Out:
# (4895, 16)

# %%
df.drop(columns=["day"],inplace = True)
df.head()
# Out:
#    id                name   manner_of_death       armed   age gender  \
# 0   3          Tim Elliot              shot         gun  53.0      M
# 1   4    Lewis Lee Lembke              shot         gun  47.0      M
# 2   5  John Paul Quintero  shot and Tasered     unarmed  23.0      M
# 3   8     Matthew Hoffman              shot  toy weapon  32.0      M
# 4   9   Michael Rodriguez              shot    nail gun  39.0      M
#
#        race           city state  signs_of_mental_illness threat_level  \
# 0     Asian        Shelton    WA                     True       attack
# 1     White          Aloha    OR                    False       attack
# 2  Hispanic        Wichita    KS                    False        other
# 3     White  San Francisco    CA                     True       attack
# 4  Hispanic          Evans    CO                    False       attack
#
#           flee  body_camera          arms_category  year
# 0  Not fleeing        False                   Guns  2015
# ...

# %%
df.shape
# Out:
# (4895, 15)

# %%
# convert the year column to datetime using:
# policeShootings["year"] = pd.to_datetime(policeShootings["year"])
police_Shootings["year"] = pd.to_datetime(police_Shootings["year"])

# %%
police_Shootings.dtypes
# Out:
# id                                  int64
# name                               object
# manner_of_death                    object
# armed                              object
# age                               float64
# gender                             object
# race                               object
# city                               object
# state                              object
# signs_of_mental_illness              bool
# threat_level                       object
# flee                               object
# body_camera                          bool
# arms_category                      object
# year                       datetime64[ns]
# dtype: object

# %%
# print the first 3 rows
df.iloc[0:3]
# Out:
#    id                name   manner_of_death    armed   age gender      race  \
# 0   3          Tim Elliot              shot      gun  53.0      M     Asian
# 1   4    Lewis Lee Lembke              shot      gun  47.0      M     White
# 2   5  John Paul Quintero  shot and Tasered  unarmed  23.0      M  Hispanic
#
#       city state  signs_of_mental_illness threat_level         flee  \
# 0  Shelton    WA                     True       attack  Not fleeing
# 1    Aloha    OR                    False       attack  Not fleeing
# 2  Wichita    KS                    False        other  Not fleeing
#
#    body_camera arms_category       year
# 0        False          Guns 2015-01-01
# 1        False          Guns 2015-01-01
# 2        False       Unarmed 2015-01-01

# %%
# check the number of values in each class in the 'year' column

# %%
df["year"].value_counts()
# Out:
# 2015-01-01    965
# 2017-01-01    906
# 2016-01-01    904
# 2018-01-01    888
# 2019-01-01    858
# 2020-01-01    374
# Name: year, dtype: int64

# %%
# in this code cell drop any other columns you think may be irrelevant

# %%
df.drop(columns=["id"],inplace= True)
df.head()
# Out:
#                  name   manner_of_death       armed   age gender      race  \
# 0          Tim Elliot              shot         gun  53.0      M     Asian
# 1    Lewis Lee Lembke              shot         gun  47.0      M     White
# 2  John Paul Quintero  shot and Tasered     unarmed  23.0      M  Hispanic
# 3     Matthew Hoffman              shot  toy weapon  32.0      M     White
# 4   Michael Rodriguez              shot    nail gun  39.0      M  Hispanic
#
#             city state  signs_of_mental_illness threat_level         flee  \
# 0        Shelton    WA                     True       attack  Not fleeing
# 1          Aloha    OR                    False       attack  Not fleeing
# 2        Wichita    KS                    False        other  Not fleeing
# 3  San Francisco    CA                     True       attack  Not fleeing
# 4          Evans    CO                    False       attack  Not fleeing
#
#    body_camera          arms_category       year
# ...

# %%
df.drop(columns=["name"],inplace= True)
df.head()
# Out:
#     manner_of_death       armed   age gender      race           city state  \
# 0              shot         gun  53.0      M     Asian        Shelton    WA
# 1              shot         gun  47.0      M     White          Aloha    OR
# 2  shot and Tasered     unarmed  23.0      M  Hispanic        Wichita    KS
# 3              shot  toy weapon  32.0      M     White  San Francisco    CA
# 4              shot    nail gun  39.0      M  Hispanic          Evans    CO
#
#    signs_of_mental_illness threat_level         flee  body_camera  \
# 0                     True       attack  Not fleeing        False
# 1                    False       attack  Not fleeing        False
# 2                    False        other  Not fleeing        False
# 3                     True       attack  Not fleeing        False
# 4                    False       attack  Not fleeing        False
#
#            arms_category       year
# 0                   Guns 2015-01-01
# 1                   Guns 2015-01-01
# ...

# %%
# rearrange the columns by reindex()function
df = df.reindex(columns = ["year","manner_of_death","armed","age","gender","race","city","state","signs_of_mental_illnes",
                                                "threat_level","flee","body_camera","arms_category"])
print(df)
# Out:
#            year   manner_of_death       armed   age gender      race  \
# 0    2015-01-01              shot         gun  53.0      M     Asian
# 1    2015-01-01              shot         gun  47.0      M     White
# 2    2015-01-01  shot and Tasered     unarmed  23.0      M  Hispanic
# 3    2015-01-01              shot  toy weapon  32.0      M     White
# 4    2015-01-01              shot    nail gun  39.0      M  Hispanic
# ...         ...               ...         ...   ...    ...       ...
# 4890 2020-01-01              shot       Taser  27.0      M     Black
# 4891 2020-01-01              shot         gun  23.0      M     Black
# 4892 2020-01-01              shot     unarmed  25.0      F     White
# 4893 2020-01-01              shot         gun  22.0      M     White
# 4894 2020-01-01              shot         gun  31.0      M     White
#
#                city state  signs_of_mental_illnes threat_level         flee  \
# ...

# %%
df= pd.DataFrame(df)
df
# Out:
#            year   manner_of_death       armed   age gender      race  \
# 0    2015-01-01              shot         gun  53.0      M     Asian
# 1    2015-01-01              shot         gun  47.0      M     White
# 2    2015-01-01  shot and Tasered     unarmed  23.0      M  Hispanic
# 3    2015-01-01              shot  toy weapon  32.0      M     White
# 4    2015-01-01              shot    nail gun  39.0      M  Hispanic
# ...         ...               ...         ...   ...    ...       ...
# 4890 2020-01-01              shot       Taser  27.0      M     Black
# 4891 2020-01-01              shot         gun  23.0      M     Black
# 4892 2020-01-01              shot     unarmed  25.0      F     White
# 4893 2020-01-01              shot         gun  22.0      M     White
# 4894 2020-01-01              shot         gun  31.0      M     White
#
#                city state  signs_of_mental_illnes threat_level         flee  \
# ...

# %%
# When you are done with the data preprocessing, export your data as a csv to your drive. 
# Remember to set index to false.
df.to_csv("pg_shootings.csv",index = False)

# %%
pg_shootings = pd.read_csv(r"C:\Users\OJ SYSTEMS\Desktop\pg_shootings.csv")

# %%
pg_shootings.head()
# Out:
#          year   manner_of_death       armed   age gender      race  \
# 0  2015-01-01              shot         gun  53.0      M     Asian
# 1  2015-01-01              shot         gun  47.0      M     White
# 2  2015-01-01  shot and Tasered     unarmed  23.0      M  Hispanic
# 3  2015-01-01              shot  toy weapon  32.0      M     White
# 4  2015-01-01              shot    nail gun  39.0      M  Hispanic
#
#             city state  signs_of_mental_illnes threat_level         flee  \
# 0        Shelton    WA                     NaN       attack  Not fleeing
# 1          Aloha    OR                     NaN       attack  Not fleeing
# 2        Wichita    KS                     NaN        other  Not fleeing
# 3  San Francisco    CA                     NaN       attack  Not fleeing
# 4          Evans    CO                     NaN       attack  Not fleeing
#
#    body_camera          arms_category
# 0        False                   Guns
# 1        False                   Guns
# ...

# %%
pg_shootings.tail(3000)
# Out:
#             year   manner_of_death            armed   age gender      race  \
# 1895  2017-01-01  shot and Tasered          unarmed  23.0      M     Black
# 1896  2017-01-01              shot  air conditioner  41.0      M     White
# 1897  2017-01-01              shot              gun  41.0      M     Other
# 1898  2017-01-01              shot              gun  38.0      M  Hispanic
# 1899  2017-01-01              shot              gun  54.0      M     White
# ...          ...               ...              ...   ...    ...       ...
# 4890  2020-01-01              shot            Taser  27.0      M     Black
# 4891  2020-01-01              shot              gun  23.0      M     Black
# 4892  2020-01-01              shot          unarmed  25.0      F     White
# 4893  2020-01-01              shot              gun  22.0      M     White
# 4894  2020-01-01              shot              gun  31.0      M     White
#
# ...

# %%
#Here, set your mind open to asking important questions which your data should be able to answer.

#For example what year were killings done the most, what gender are shot the most, what races are shot the most, etc...

#For every question you ask, plot a chart that will answer it, and write a markdown to state your findings from the plot.

# %%
arms_Used_most = pg_shootings.arms_category.value_counts()

# %%
arms_Used_most
# Out:
# Guns                     2764
# Sharp objects             818
# Unknown                   418
# Unarmed                   348
# Other unusual objects     192
# Blunt instruments         122
# Vehicles                  121
# Multiple                   54
# Piercing objects           29
# Electrical devices         24
# Explosives                  4
# Hand tools                  1
# Name: arms_category, dtype: int64

# %%
arms_Used_most.index
# Out:
# Index(['Guns', 'Sharp objects', 'Unknown', 'Unarmed', 'Other unusual objects',
#        'Blunt instruments', 'Vehicles', 'Multiple', 'Piercing objects',
#        'Electrical devices', 'Explosives', 'Hand tools'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 7))
plt.xticks(rotation=65)
plt.title("Death by arms Category")
sns.barplot(arms_Used_most.index, arms_Used_most)
plt.ylabel('Number of deaths')
# Out:
# Text(0, 0.5, 'Number of deaths')

# %%
cityTop10_most_shot = pg_shootings.city.value_counts().head(10)

# %%
cityTop10_most_shot
# Out:
# Los Angeles      78
# Phoenix          66
# Houston          51
# Las Vegas        41
# San Antonio      40
# Chicago          38
# Columbus         36
# Albuquerque      32
# Jacksonville     31
# Oklahoma City    30
# Name: city, dtype: int64

# %%
cityTop10_most_shot.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Las Vegas', 'San Antonio',
#        'Chicago', 'Columbus', 'Albuquerque', 'Jacksonville', 'Oklahoma City'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 7))
plt.title('City were policeshootings occurred most')
plt.xticks(rotation=60)
sns.barplot(cityTop10_most_shot.index,cityTop10_most_shot )
plt.ylabel('Number of deaths')
# Out:
# Text(0, 0.5, 'Number of deaths')

# %%
threatLevel = pg_shootings.threat_level.value_counts()

# %%
threatLevel
# Out:
# attack          3160
# other           1528
# undetermined     207
# Name: threat_level, dtype: int64

# %%
threatLevel.index
# Out:
# Index(['attack', 'other', 'undetermined'], dtype='object')

# %%
plt.figure(figsize=(10, 7))
plt.xticks(rotation=60)
plt.title("Threat level at the police shooting")
sns.barplot(threatLevel.index, threatLevel)
plt.ylabel('Number of deaths')
# Out:
# Text(0, 0.5, 'Number of deaths')

# %%
fleeVictims =pg_shootings.flee.value_counts()

# %%
fleeVictims
# Out:
# Not fleeing    3073
# Car             820
# Foot            642
# Other           360
# Name: flee, dtype: int64

# %%
fleeVictims.index
# Out:
# Index(['Not fleeing', 'Car', 'Foot', 'Other'], dtype='object')

# %%
plt.figure(figsize =(20,10))
plt.xticks(rotation = 60)
plt.title('To ascertain if the victims flee or not')
sns.barplot(fleeVictims.index,fleeVictims)
plt.ylabel('Number of deaths')
# Out:
# Text(0, 0.5, 'Number of deaths')

# %%
bodyCAM =pg_shootings.body_camera.value_counts()

# %%
bodyCAM
# Out:
# False    4317
# True      578
# Name: body_camera, dtype: int64

# %%
bodyCAM.index
# Out:
# Index([False, True], dtype='object')

# %%
plt.figure(figsize=(10, 7))
plt.xticks(rotation=60)
plt.title('To ascertain body camera')
sns.barplot(bodyCAM.index, bodyCAM)
plt.ylabel('Number of deaths')
# Out:
# Text(0, 0.5, 'Number of deaths')

# %%
# check the number of values in each class in the 'year' column
year_most_killed = pg_shootings.year.value_counts()

# %%
year_most_killed
# Out:
# 2015-01-01    965
# 2017-01-01    906
# 2016-01-01    904
# 2018-01-01    888
# 2019-01-01    858
# 2020-01-01    374
# Name: year, dtype: int64

# %%
year_most_killed.index
# Out:
# Index(['2015-01-01', '2017-01-01', '2016-01-01', '2018-01-01', '2019-01-01',
#        '2020-01-01'],
#       dtype='object')

# %%
#importing required packages
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('darkgrid')
plt.figure(figsize=(9,5))
plt.figure.facecolor = '#00000000'
sns.barplot(year_most_killed.index, year_most_killed, palette='rainbow',)
plt.title("The number killed by year")
plt.ylabel('number_of deaths')
plt.xlabel("year_most_killed")
# Out:
# Text(0.5, 0, 'year_most_killed')

# %%
# check the number of values in each class in the 'gender' column
gender_shot_most = pg_shootings.gender.value_counts()

# %%
gender_shot_most
# Out:
# M    4673
# F     222
# Name: gender, dtype: int64

# %%
gender_shot_most.index
# Out:
# Index(['M', 'F'], dtype='object')

# %%
plt.title("gender_shot_most")
plt.pie(gender_shot_most, labels=gender_shot_most.index, autopct='%1.1f%%', shadow = True, wedgeprops ={'edgecolor':'black'} , startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x26391e77be0>,
# ...
#  [Text(1.0888537659492934, -0.15619691539221137, 'M'),
#   Text(-1.0888537659492932, 0.15619691539221248, 'F')],
#  [Text(0.5939202359723418, -0.08519831748666074, '95.5%'),
#   Text(-0.5939202359723417, 0.08519831748666133, '4.5%')])

# %%
# check the number of values in each class in the 'race' column
race_shot_most = pg_shootings.race.value_counts()

# %%
race_shot_most
# Out:
# White       2476
# Black       1298
# Hispanic     902
# Asian         93
# Native        78
# Other         48
# Name: race, dtype: int64

# %%
race_shot_most.index
# Out:
# Index(['White', 'Black', 'Hispanic', 'Asian', 'Native', 'Other'], dtype='object')

# %%
# importing required packages
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('darkgrid')
plt.figure(figsize=(9,5))
plt.figure.facecolor = '#00000000'
sns.barplot(race_shot_most.index, race_shot_most, palette = 'rainbow')
plt.title("The number killed by race")
plt.ylabel('Number of deaths')
plt.xlabel("race affected")
# Out:
# Text(0.5, 0, 'race affected')

# %%
pg_shootings.age
# Out:
# 0       53.0
# 1       47.0
# 2       23.0
# 3       32.0
# 4       39.0
#         ...
# 4890    27.0
# 4891    23.0
# 4892    25.0
# 4893    22.0
# 4894    31.0
# Name: age, Length: 4895, dtype: float64

# %%
# the range of ages that were shot the most
# plotting a histogram to know the range of ages that was killed mostly
# the bin for the histogram np.arange(5,100,5)
# that shows the starting point, the interval and stop pont
import numpy as np
plt.figure(figsize=(20, 10))
plt.title("Age shot most")
plt.xlabel('Age')
plt.ylabel('Number of deaths')
plt.hist(pg_shootings.age, bins=np.arange(5,100,5), color='green');

# %%
# to find out which state recorded the highest most shot 

state_most_shot=pg_shootings.state.value_counts()

# %%
state_most_shot
# Out:
# CA    701
# TX    426
# FL    324
# AZ    222
# CO    168
# GA    161
# OK    151
# NC    148
# OH    146
# WA    126
# TN    125
# MO    124
# LA    102
# IL     99
# AL     95
# PA     95
# NM     93
# VA     92
# IN     91
# NY     90
# WI     88
# KY     87
# NV     85
# SC     80
# MD     77
# OR     76
# AR     73
# MI     71
# MS     61
# MN     60
# NJ     60
# UT     58
# KS     49
# WV     46
# ID     37
# AK     36
# MA     33
# IA     31
# MT     29
# HI     29
# NE     24
# ME     21
# CT     20
# SD     14
# WY     13
# DC     13
# NH     12
# ND     11
# DE     10
# VT      8
# RI      4
# Name: state, dtype: int64

# %%
state_most_shot.index
# Out:
# Index(['CA', 'TX', 'FL', 'AZ', 'CO', 'GA', 'OK', 'NC', 'OH', 'WA', 'TN', 'MO',
#        'LA', 'IL', 'AL', 'PA', 'NM', 'VA', 'IN', 'NY', 'WI', 'KY', 'NV', 'SC',
#        'MD', 'OR', 'AR', 'MI', 'MS', 'MN', 'NJ', 'UT', 'KS', 'WV', 'ID', 'AK',
#        'MA', 'IA', 'MT', 'HI', 'NE', 'ME', 'CT', 'SD', 'WY', 'DC', 'NH', 'ND',
#        'DE', 'VT', 'RI'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
plt.title("states most killed")
sns.barplot(state_most_shot.index,state_most_shot)
plt.ylabel("Numbers of death")
# Out:
# Text(0, 0.5, 'Numbers of death')

# %%
mannerOf_Death = pg_shootings.manner_of_death.value_counts()

# %%
mannerOf_Death
# Out:
# shot                4647
# shot and Tasered     248
# Name: manner_of_death, dtype: int64
